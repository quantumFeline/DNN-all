# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1_utx_ZGclmCwNttSe40kYA6VHzNocdET' height="60"></center>
#
# AI TECH - Akademia Innowacyjnych Zastosowań Technologii Cyfrowych. Programu Operacyjnego Polska Cyfrowa na lata 2014-2020
# <hr>
#
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
#
# <center>
# Projekt współfinansowany ze środków Unii Europejskiej w ramach Europejskiego Funduszu Rozwoju Regionalnego
# Program Operacyjny Polska Cyfrowa na lata 2014-2020,
# Oś Priorytetowa nr 3 "Cyfrowe kompetencje społeczeństwa" Działanie  nr 3.2 "Innowacyjne rozwiązania na rzecz aktywizacji cyfrowej"
# Tytuł projektu:  „Akademia Innowacyjnych Zastosowań Technologii Cyfrowych (AI Tech)”
#     </center>

# %% [markdown]
# # Simple linear regression
#
# In this exercise you will train a linear regression model via gradient descent in the simplest scenario, i.e. recreating an affine function.
#
# The setup is as follows:
# * we are given a set of pairs $(x, y)$, where $x$ represents the feature, and $y$ is the target,
# * our hypothesis is $h(x) = ax + b$,
# * we will use the dataset consisting of set of pairs to figure out the right values for $a$ and $b$,
# * to do so we will optimize the loss function: $J(a,b) = \frac{1}{n}\sum_{i=1}^n (y_i - h(x_i))^2$,
# * with the loss function in hand we can improve our guesses iteratively:
#     * $a^{t+1} = a^t - \text{step_size} \cdot \frac{\partial J(a,b)}{\partial a}$,
#     * $b^{t+1} = b^t - \text{step_size} \cdot \frac{\partial J(a,b)}{\partial b}$,
# * we can end the process after some predefined number of epochs (or when the changes are no longer meaningful).
#
# Let's start with creating the dataset.

# %%
import random

_a = 0.3
_b = 0.5

f = lambda x: _a * x + _b # ground truth
g = lambda x: f(x) + random.gauss(0, 0.02) # a noisy version of f

# %%
n = 50 # number of examples

xs = [random.random() for _ in range(n)] # features
ys = list(map(g, xs)) # targets

ts = list(map(f, xs)) # we don't get to see this

# %% [markdown]
# Our goal is to recreate $f$. However, as reality can be harsh (and usually is) we only get to observe $g$. We observe it as a list of pairs $(x,y) \in \text{zip}(xs, ys)$.
#
# Let's plot the data. We will use the `plotly` library to make the plots interactive, which allows for easier inspection of data.

# %%
# !pip install -q plotly==4.2.1

# %%
import plotly.graph_objects as go
import plotly.express as px

fig = px.scatter(x=xs, y=ys)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="36272870-8547-4d7b-91fd-923a0be5e912" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("36272870-8547-4d7b-91fd-923a0be5e912")) {                    Plotly.newPlot(                        "36272870-8547-4d7b-91fd-923a0be5e912",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"ie0pNLi16T\u002fOFrzfb+vRP4Vnri2\u002fS+0\u002ffyU57oJ76T9iKvRTNTHYP8RLaTi\u002f\u002feE\u002fQmxN+iKi6j+G\u002fE9Kk+rsP7L2w0gZlNg\u002fYK93F8o2mT\u002f4WiumqNXPPxx37vRAJuA\u002fxMy6tnCHxT9vy9keO8TgPyh2dbsVHus\u002fkGwZPit\u002frT9sypwsw17nPzssAVAfcOI\u002foIlppdS8mz\u002f5Sz4wy7nsP2w80t+Z0Ng\u002foAxbIPmiwz8XuYCjgLXrP9Q2wOx1Cdc\u002fuo76z2aZ1T+azmTlmEvSP1oW6HZtpNI\u002f6DMTt1pZ2z\u002fAi36Cqq+dP\u002fDluyEy0eA\u002fgMmOg3sjqD8sJFxLb8TuPz8QI\u002fxotuI\u002f8KSYeCg3wD8QidIBNz6pP9bYBOT0h+c\u002fqglbo+4S5D+gZO6Hrvi0P9hXdVwO58Y\u002fMgFpUz5j7D8MiOM7IGnhP3MY1EWnAOY\u002fOmrbSZFG5z+QCETCIV+gP9DzBqbR0+k\u002f1q64W4P46j8ofqN8+wTOP\u002fj9ZUzq7sQ\u002f2afRyvF+7D+SBsyNfhLsPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"HKE8aUx25z\u002fkay8nH5DiP\u002fUkWEBRg+k\u002fOugvCj0W5z8Ap8v869zjP19qXoB8EOU\u002fpVqaMkQ85z\u002fOjMdRYeToP0gaUPglPOM\u002fKKoRQn1a4D\u002fvflb+r6vhPyTYfBb1P+U\u002fs2QUhuls4D\u002fWr2irh3fkP82dIZQis+g\u002fkPvM7I184D\u002fCXyPOq2jnP7uEu8vFUeY\u002f8T2GfkWk3z+tYZ4zoEfoP3VQVzy1eeM\u002fgMDvCR704D9pOHIY+GDoP4hOnsUvs+M\u002fNkESRE2L4z\u002fNNRIlJn3jP3nh4eIW\u002fuM\u002fdPn8tI3q4z+HvXo+GdreP4efxwUlseU\u002fgVgws+g84D9McU6IznPoP2Fy\u002fxrtaeU\u002fugTnKNiN4T\u002fY0VnKa4\u002fgP3tJ+CZlG+Y\u002fvDNyohHU5T\u002febGLPoHbhP1YqvZ0+pOI\u002fzTeMhKmu6T+g4EUAJhjmP9F6L7T2A+c\u002fSYgxCOXQ5j8DhZZ1D4reP7phHJGaJ+g\u002fOTPs2ArG6D++w87ShebhPyTNEbf0h+I\u002ft48qYIkg6T9pM88lnmPoPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}] ...

# %%
import numpy as np

def mse_loss(ys, ps):
    assert len(ys) == len(ps)
    ys = np.array(ys)
    ps = np.array(ps)

    ### YOUR CODE BEGINS HERE ###
    return (np.sum((ys - ps)**2))
    ### YOUR CODE ENDS HERE ###

# %% [markdown]
# Please take a while to (roughly) guess the output before executing the cell below.

# %%
print(mse_loss(ys, ts))
# Out:
# 0.017442943141719354

# %% [markdown]
# Let's now implement the algorithm
#
# Hint: To make sure that you correctly compute the gradients, you can compute them numerically and compare the results.

# %%
a = 0. # our initial guess for _a
b = 0. # our initial guess for _b
lr = 0.5 # step size

n_epochs = 40 # number of passes over the training data
xs = np.array(xs)
n = xs.shape[0]

def predict(a: float, b: float, xs: np.array = xs):
    return a * xs + np.full(xs.shape, b)
    #return [a * x + b for x in xs]

def evaluate(a, b, xs=xs, ys=ys):
    return mse_loss(ys, predict(a, b, xs))

def update_a(xs: np.array, ys: np.array, ps: np.array):
    return np.sum(2 * (ps - ys) * xs) / n * lr

def update_b(ys: np.array, ps: np.array):
    return np.sum(2 * (ps - ys)) / n * lr

losses = [evaluate(a, b)]

for i in range(n_epochs):
    #############################
    # TODO: Fill in the details #
    #############################
    ### YOUR CODE BEGINS HERE ###
    predictions = predict(a, b, xs)
    #print(update_a(xs, ys, predictions))
    #print(update_b(ys, predictions))
    a -= update_a(xs, ys, predictions)
    b -= update_b(ys, predictions)
    ### YOUR CODE ENDS HERE ###

    loss = evaluate(a, b)
    losses.append(loss)

    print(f'Iter: {i:>3} Loss: {loss:8.8f} a: {a:8.5f}, b: {b:8.5f}')
# Out:
# Iter:   0 Loss: 1.39697171 a:  0.34236, b:  0.64667
# Iter:   1 Loss: 0.11030773 a:  0.25879, b:  0.48089
# Iter:   2 Loss: 0.02684792 a:  0.28303, b:  0.52135
# Iter:   3 Loss: 0.02092461 a:  0.27969, b:  0.50962
# Iter:   4 Loss: 0.02007218 a:  0.28314, b:  0.51123
# Iter:   5 Loss: 0.01961478 a:  0.28467, b:  0.50956
# Iter:   6 Loss: 0.01924145 a:  0.28650, b:  0.50882
# Iter:   7 Loss: 0.01892364 a:  0.28809, b:  0.50794
# Iter:   8 Loss: 0.01865220 a:  0.28958, b:  0.50717
# Iter:   9 Loss: 0.01842031 a:  0.29095, b:  0.50645
# Iter:  10 Loss: 0.01822220 a:  0.29222, b:  0.50578
# Iter:  11 Loss: 0.01805296 a:  0.29340, b:  0.50516
# Iter:  12 Loss: 0.01790837 a:  0.29449, b:  0.50460
# Iter:  13 Loss: 0.01778485 a:  0.29549, b:  0.50407
# Iter:  14 Loss: 0.01767933 a:  0.29642, b:  0.50358
# Iter:  15 Loss: 0.01758918 a:  0.29727, b:  0.50314
# Iter:  16 Loss: 0.01751216 a:  0.29807, b:  0.50272
# Iter:  17 Loss: 0.01744637 a:  0.29880, b:  0.50234
# Iter:  18 Loss: 0.01739016 a:  0.29948, b:  0.50198
# Iter:  19 Loss: 0.01734214 a:  0.30010, b:  0.50165
# Iter:  20 Loss: 0.01730112 a:  0.30068, b:  0.50135
# Iter:  21 Loss: 0.01726607 a:  0.30121, b:  0.50107
# Iter:  22 Loss: 0.01723613 a:  0.30171, b:  0.50081
# Iter:  23 Loss: 0.01721055 a:  0.30217, b:  0.50057
# Iter:  24 Loss: 0.01718870 a:  0.30259, b:  0.50035
# Iter:  25 Loss: 0.01717003 a:  0.30298, b:  0.50015
# Iter:  26 Loss: 0.01715408 a:  0.30334, b:  0.49996
# Iter:  27 Loss: 0.01714046 a:  0.30367, b:  0.49978
# Iter:  28 Loss: 0.01712882 a:  0.30398, b:  0.49962
# Iter:  29 Loss: 0.01711887 a:  0.30426, b:  0.49947
# Iter:  30 Loss: 0.01711038 a:  0.30453, b:  0.49933
# Iter:  31 Loss: 0.01710312 a:  0.30477, b:  0.49921
# Iter:  32 Loss: 0.01709692 a:  0.30500, b:  0.49909
# Iter:  33 Loss: 0.01709162 a:  0.30520, b:  0.49898
# Iter:  34 Loss: 0.01708710 a:  0.30540, b:  0.49888
# Iter:  35 Loss: 0.01708323 a:  0.30557, b:  0.49879
# Iter:  36 Loss: 0.01707993 a:  0.30574, b:  0.49870
# Iter:  37 Loss: 0.01707711 a:  0.30589, b:  0.49862
# Iter:  38 Loss: 0.01707470 a:  0.30603, b:  0.49855
# Iter:  39 Loss: 0.01707264 a:  0.30616, b:  0.49848

# %%
fig = px.line(y=losses, labels={'y':'loss'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="bced99b1-5c16-486a-979b-5da9d3cefec2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bced99b1-5c16-486a-979b-5da9d3cefec2")) {                    Plotly.newPlot(                        "bced99b1-5c16-486a-979b-5da9d3cefec2",                        [{"hovertemplate":"x=%{x}\u003cbr\u003eloss=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"i1","bdata":"AAECAwQFBgcICQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJyg="},"xaxis":"x","y":{"dtype":"f8","bdata":"hthVKTVgNUBO4UgD\u002f1n2P0C9f5sgPbw\u002fpadySwV+mz\u002fnij37Qm2VP5LbmnTNjZQ\u002fOaopxOUVlD\u002fV\u002fdEJCLSTPyS7y723YJM\u002fYaYAqY8Zkz\u002fKF5rVxdySP\u002fREe0TXqJI\u002fj6JVnnl8kj9uhymxklaSP9qJXGgxNpI\u002fJ\u002fH7zocakj90VbTx5QKSP+AHqn+17pE\u002fgyBfDnbdkT9ngeXouc6RPy1pEVYjwpE\u002fJiBWRGK3kT+\u002f8nxMMq6RP9Yaj\u002f5YppE\u002ffS0jbqSfkT+J09H06ZmRP2wG7iIFlZE\u002f707D19aQkT\u002fL55d7RI2RP3Brh1Y3ipE\u002fNC0CAJyHkT9gHlrjYYWRPw4ITNZ6g5E\u002fXkjmvtqBkT97\u002fo9Gd4CRP2kOR5hHf5E\u002foLlyKER+kT+feuWEZn2RP63f3CupfJE\u002fvJr6aAd8kT87+1c3fXuRPw=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}} ...

# %% [markdown]
# Let's now visually asses how we do on training data

# %%
fig = go.Figure()

fig = px.scatter(x=xs, y=ys)
dense_x = np.linspace(np.min(xs), np.max(xs), 100)
fig.add_trace(go.Scatter(x=dense_x, y=predict(a, b, dense_x), name='linear fit', mode='lines'))
fig.add_trace(go.Scatter(x=xs, y=ts, name='y without noise', mode='markers'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="5ec43266-0c11-476d-9c88-708eaaae425c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5ec43266-0c11-476d-9c88-708eaaae425c")) {                    Plotly.newPlot(                        "5ec43266-0c11-476d-9c88-708eaaae425c",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"ie0pNLi16T\u002fOFrzfb+vRP4Vnri2\u002fS+0\u002ffyU57oJ76T9iKvRTNTHYP8RLaTi\u002f\u002feE\u002fQmxN+iKi6j+G\u002fE9Kk+rsP7L2w0gZlNg\u002fYK93F8o2mT\u002f4WiumqNXPPxx37vRAJuA\u002fxMy6tnCHxT9vy9keO8TgPyh2dbsVHus\u002fkGwZPit\u002frT9sypwsw17nPzssAVAfcOI\u002foIlppdS8mz\u002f5Sz4wy7nsP2w80t+Z0Ng\u002foAxbIPmiwz8XuYCjgLXrP9Q2wOx1Cdc\u002fuo76z2aZ1T+azmTlmEvSP1oW6HZtpNI\u002f6DMTt1pZ2z\u002fAi36Cqq+dP\u002fDluyEy0eA\u002fgMmOg3sjqD8sJFxLb8TuPz8QI\u002fxotuI\u002f8KSYeCg3wD8QidIBNz6pP9bYBOT0h+c\u002fqglbo+4S5D+gZO6Hrvi0P9hXdVwO58Y\u002fMgFpUz5j7D8MiOM7IGnhP3MY1EWnAOY\u002fOmrbSZFG5z+QCETCIV+gP9DzBqbR0+k\u002f1q64W4P46j8ofqN8+wTOP\u002fj9ZUzq7sQ\u002f2afRyvF+7D+SBsyNfhLsPw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"HKE8aUx25z\u002fkay8nH5DiP\u002fUkWEBRg+k\u002fOugvCj0W5z8Ap8v869zjP19qXoB8EOU\u002fpVqaMkQ85z\u002fOjMdRYeToP0gaUPglPOM\u002fKKoRQn1a4D\u002fvflb+r6vhPyTYfBb1P+U\u002fs2QUhuls4D\u002fWr2irh3fkP82dIZQis+g\u002fkPvM7I184D\u002fCXyPOq2jnP7uEu8vFUeY\u002f8T2GfkWk3z+tYZ4zoEfoP3VQVzy1eeM\u002fgMDvCR704D9pOHIY+GDoP4hOnsUvs+M\u002fNkESRE2L4z\u002fNNRIlJn3jP3nh4eIW\u002fuM\u002fdPn8tI3q4z+HvXo+GdreP4efxwUlseU\u002fgVgws+g84D9McU6IznPoP2Fy\u002fxrtaeU\u002fugTnKNiN4T\u002fY0VnKa4\u002fgP3tJ+CZlG+Y\u002fvDNyohHU5T\u002febGLPoHbhP1YqvZ0+pOI\u002fzTeMhKmu6T+g4EUAJhjmP9F6L7T2A+c\u002fSYgxCOXQ5j8DhZZ1D4reP7phHJGaJ+g\u002fOTPs2ArG6D++w87ShebhPyTNEbf0h+I\u002ft48qYIkg6T9pM88lnmPoPw=="},"yaxis":"y","type":"scatter"},{"mode":"lines","name":"linear fit","x":{"dtype":"f8","bdata":"YK93F8o2mT+1moUAwXOhP7pdT\u002fUcTKY\u002fwCAZ6ngkqz\u002fF4+Le1PyvP2VT1mmYarI\u002f6DQ7ZMbWtD9qFqBe9EK3P+33BFkir7k\u002fcNlpU1AbvD\u002fyus5Nfoe+PzrOGSTWecA\u002f\u002fD5MIe2vwT+9r34eBObCP34gsRsbHMQ\u002fQJHjGDJSxT8BAhYWSYjGP8JySBNgvsc\u002fhON6EHf0yD9FVK0NjirKPwbF3wqlYMs\u002fyDUSCLyWzD+JpkQF08zNP0oXdwLqAs8\u002fBsTUf4Ac0D9m\u002fG3+i7fQP8c0B32XUtE\u002fKG2g+6Lt0T+IpTl6rojSP+nd0vi5I9M\u002fShZsd8W+0z+qTgX20FnUPwuHnnTc9NQ\u002fbL838+eP1T\u002fM99Bx8yrWPy0wavD+xdY\u002fjmgDbwph1z\u002fuoJztFfzXP0\u002fZNWwhl9g\u002fsBHP6iwy2T8QSmhpOM3ZP3GCAehDaNo\u002f0rqaZk8D2z8y8zPlWp7bP5MrzWNmOdw\u002f9GNm4nHU3D9UnP9gfW\u002fdP7XUmN+ICt4\u002fFg0yXpSl3j92Rcvcn0DfP9d9ZFur298\u002fHNv+bFs74D9Md0ss4YjgP3wTmOtm1uA\u002fra\u002fkquwj4T\u002fdSzFqcnHhPw3ofSn4vuE\u002fPoTK6H0M4j9uIBeoA1riP568Y2eJp+I\u002fz1iwJg\u002f14j\u002f\u002f9PzllELjPy+RSaUakOM\u002fYC2WZKDd4z+QyeIjJivkP8BlL+OreOQ\u002f8QF8ojHG5D8hnshhtxPlP1E6FSE9YeU\u002fgtZh4MKu5T+ycq6fSPzlP+IO+17OSeY\u002fE6tHHlSX5j9DR5Td2eTmP3Pj4JxfMuc\u002fpH8tXOV\u002f5z\u002fUG3oba83nPwS4xtrwGug\u002fNVQTmnZo6D9l8F9Z\u002fLXoP5WMrBiCA+k\u002fxij51wdR6T\u002f2xEWXjZ7pPyZhklYT7Ok\u002fV\u002f3eFZk56j+HmSvVHofqP7c1eJSk1Oo\u002f6NHEUyoi6z8YbhETsG\u002frP0gKXtI1ves\u002feaaqkbsK7D+pQvdQQVjsP9neQxDHpew\u002fCnuQz0zz7D86F92O0kDtP2qzKU5Yju0\u002fm092Dd7b7T\u002fL68LMYynuP\u002fuHD4zpdu4\u002fLCRcS2\u002fE7j8="},"y":{"dtype":"f8","bdata":"hTW+uU0x4D9XeVSvCUngPyi96qTFYOA\u002f+QCBmoF44D\u002fLRBeQPZDgP5yIrYX5p+A\u002fbcxDe7W\u002f4D8\u002fENpwcdfgPxBUcGYt7+A\u002f4pcGXOkG4T+z25xRpR7hP4QfM0dhNuE\u002fVmPJPB1O4T8np18y2WXhP\u002fjq9SeVfeE\u002fyi6MHVGV4T+bciITDa3hP2y2uAjJxOE\u002fPvpO\u002foTc4T8PPuXzQ ...

# %% [markdown]
# Let's check our implementation vs. the one in sklearn and numpy.

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array(xs).reshape((len(xs), 1))
regr = LinearRegression()
regr.fit(X, ys) # training

sk_a = float(regr.coef_)
sk_b = regr.intercept_
sk_loss = mse_loss(ys, regr.predict(X))

print(f'Loss: {sk_loss:8.8f} a: {sk_a:8.5f}, b: {sk_b:8.5f}')
# Out:
# Loss: 0.01706056 a:  0.30774, b:  0.49765
# /tmp/ipython-input-2833494271.py:8: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)

# %%
z = np.polyfit(x=xs, y=ys, deg=1)
print(z)
f = np.poly1d(z)
print(f)
# Out:
# [0.30774127 0.4976511 ]
#
# 0.3077 x + 0.4977

# %% [markdown]
# <center><img src='https://drive.google.com/uc?id=1BXZ0u3562N_MqCLcekI-Ens77Kk4LpPm'></center>
